# %% [markdown]
# # Visualitzation of stroke dataset

# %% [markdown]
# ### Loading

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_pickle('data/clean_reduced.pkl')
pd.set_option("display.precision", 2)

# %%
df.head()
# Out:
#       gender   age  hypertension  heart_disease  ever_married work_type  \
# 2857       1  23.0             0              0             1   Private
# 2590       1  13.0             0              0             0  children
# 4201       0  43.0             0              0             1   Private
# 2340       0  19.0             0              0             0   Private
# 4392       1   7.0             0              0             0  children
#
#       Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 2857               0             102.88  38.9          Unknown       0
# 2590               1             105.22  18.4          Unknown       0
# 4201               0             207.37  29.5  formerly smoked       0
# 2340               0              64.92  22.5          Unknown       0
# 4392               0              63.98  23.0          Unknown       0

# %% [markdown]
# ### Visualtization

# %%
sns.set_theme()

# %%
sns.displot(data=df, x="gender", hue="stroke", multiple="dodge")

# %%
sns.pairplot(df, hue='stroke')

# %%
sns.catplot(data=df, kind = "violin", x="stroke", y="age")
